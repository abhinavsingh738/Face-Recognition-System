# %%
pip install scikit-learn
# Out:
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#    --------- ------------------------------ 2.6/11.2 MB 15.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/11.2 MB 16.8 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.2 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.2/11.2 MB 14.8 MB/s  0:00:00
# ...
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# ...
#
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
# ...

# %%
pip install streamlit pandas matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/10.1 MB 13.1 MB/s eta 0:00:01
#    -------------------- ------------------- 5.2/10.1 MB 13.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.9/10.1 MB 15.4 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.1 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------- 10.1/10.1 MB 11.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    ---------------------------------------- 731.2/731.2 kB 10.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ------------------ --------------------- 3.1/6.9 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------  6.8/6.9 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 15.7 MB/s  0:00:00
# ...

# %%
pip install kaggle
# Out:
# ...
#
#    ------------- -------------------------- 1/3 [python-slugify]
#    ------------- -------------------------- 1/3 [python-slugify]
#    ------------- -------------------------- 1/3 [python-slugify]
#    -------------------------- ------------- 2/3 [kaggle]
#    -------------------------- ------------- 2/3 [kaggle]
#    -------------------------- ------------- 2/3 [kaggle]
#    -------------------------- ------------- 2/3 [kaggle]
#    -------------------------- ------------- 2/3 [kaggle]
#    -------------------------- ------------- 2/3 [kaggle]
#    -------------------------- ------------- 2/3 [kaggle]
#    -------------------------- ------------- 2/3 [kaggle]
#    -------------------------- ------------- 2/3 [kaggle]
#    -------------------------- ------------- 2/3 [kaggle]
#    -------------------------- ------------- 2/3 [kaggle]
#    -------------------------- ------------- 2/3 [kaggle]
#    -------------------------- ------------- 2/3 [kaggle]
# ...

# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
